# %%
from tkinter import *
root=Tk()
root.geometry("0x0")
def HR():
        global e10
        global l17
        global b16
        global b17
        global HR1
        global HR2
        global Age
        h=e10.get()
        something=0
        for i in e10.get():
                if(not(i.isdigit())):
                        something=1
        l17.place_forget()
        e10.place_forget()
        b16.place_forget()
        b17.place(relx=0,rely=0)
        if(something==1 or len(e10.get())==0):
                m2=("""The Heart Rate you have entered is not valid.
Please check your input""")
        
                m1=""
        elif(float(h)>220-int(Age)):
                m2=("""The Heart Rate you have entered exceeds the maximum value
for your age.
Please check your input""")
        
                m1=""
        else:
                if float(h)<49:
                        m1="Amazing Level Fitness"
                        m2="""1.This is a Best Level of Fitness!!

2.This level of fitness most desirable

3.Try maintaing this level of fitness by engaging in various physical activities

4.Following a Good diet plan and maintaining your weight will also help maintain this level of fitness!!"""
                elif float(h)>=49 and float(h) <=55:
                        m1="Athlete Level Fitness!"
                        m2="""1.Very Good Level of Fitness!!
2. Even though you have a very good Heart Beat Rate there is still a small room for improvement

3. Daily physical excersises like walking, Yoga, jogging etc will be very helpful
in maintaining as well as improving your Heart Beat Rate

4. Maintaining a good diet plan including all the necessary amounts of nourishments will be very helpful

5.Try and maintain this level of fitness!!"""
                elif float(h)>=56 and float(h)<=61:
                        m1="Excellent Fitness!"
                        m2="""1.Very Good Level of Fitness!!
2. Even though you have a very good Heart Beat Rate there is still a small room for improvement

3. Daily physical excersises like walking, Yoga, jogging etc will be very helpful
in maintaining as well as improving your Heart Beat Rate

4. Maintaining a good diet plan including all the necessary amounts of nourishments will be very helpful

5.Try and maintain this level of fitness!!"""
                elif float(h)>=62 and float(h)<=65:
                        m1="Good Fitness!"
                        m2="""1.Good Level of Fitness!!
2.Even though you have good level of fitness there is still some room for improvement

3.To improve your Heart Beat Rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.


"""
                elif float(h)>=66 and float(h)<=69:
                        m1="Above Average Fitness!"
                        m2="""1.You have a Heart Beat Rate which is slightly better than that of an average man

2.Since your Heart Beat Rate is slightly better than average, there is still a lot of room for improvement

3.To improve your Heart Beat Rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health."""
                elif float(h)>70 and float(h)<=73:
                        m1="Average Fitness!" 
                        m2="""1.You have an average Heart Beat Rate

2.Since your Heart Beat Rate is just average, improvement might be necessary

3.To improve your Heart Beat Rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.

f. Manage your stress

g. Lose weight if necessary"""
                elif float(h)>=74 and float(h)<=81:
                        m1="Below Average Fitness!"
                        m2="""1.Below Average fitness level of fitness
2. This level of fitness is the not recommended

3. If not improved, this can result in the some long term health issues

4. To improve your Heart Beat Rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.

f. Manage your stress

g. Lose weight if necessary"""
                else:
                        m1="Poor Fitness!"
                        m2="""1.Very poor fitness level of fitness
2. This level of fitness is the most undesirable

3. If not improved, this can result in the some long term health issues

4. To improve your Heart Beat Rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.

f. Manage your stress

g. Lose weight if necessary"""
        HR1=Label(root,text= m1,font=("Times New Roman",30))
        
        HR2=Label(root,text= m2,font=("Ariel",25),justify=LEFT,bd=10)
        HR1.place(relx=0.45,rely=0.1)
        HR2.place(relx=0.2,rely=0.2)
                
                
        
def HRENTRY():
        global l17
        global e10
        global b16


        delhome()
        
        l17.place(relx=0.3,rely=0.1)
        e10.place(relx=0.5,rely=0.1)
        b16.place(relx=0.7,rely=0.1)
def backHR():
        global b17
        global HR1
        global HR2
        b17.place_forget()
        HR1.place_forget()
        HR2.place_forget()
        home()

def backSUG():
        global b14
        global SUG1
        global SUG2
        b14.place_forget()
        SUG1.place_forget()
        SUG2.place_forget()
        home()
def SUGAR():
        global e9
        global l16
        global b13
        global b14
        global SUG1
        global SUG2
        s=e9.get()
        something=0
        for i in e9.get():
                if(not(i.isdigit())):
                        something=1
        l16.place_forget()
        e9.place_forget()
        b13.place_forget()
        b14.place(relx=0,rely=0)
        if(something==1 or len(e9.get())==0):
                m2=("""The Sugar Level you have entered is not valid.
Please check your input""")
                m1=""
        else:
                if float(s)<=70:
                        m1="Low Sugar Level!"
                        m2= """The Helpful Measures to increase sugar levels are:
        
1. Three to four glucose tablets.
               
2. One tube of glucose gel.
               
3. Four to six pieces of hard candy (not sugar-free).
               
4. 1/2 cup fruit juice.
               
5. 1 cup skim milk.
               
6. 1/2 cup soft drink (not sugar-free).
               
7. 1 tablespoon honey (put it under your tongue so it gets absorbed into your bloodstream faster)."""
                elif float(s)>70 and float(s)<=140:
                        m1="Normal Sugar Level!"
                        m2="""1. Your Sugar Level is under control
        
2. Maintain it by keeping healthy eating habits

3. Continue doing regular Excersises to keep it in check

4. Keep track of your Sugar Level from time to time

5. This is the desirable Sugar Level which you are expected to maintain in order
to stay healthy!!"""
                elif float(s)>=141 and float(s)<=160:
                        m1="Pre-Diabetes Sugar Level(High Sugar Level)!"
                        m2= """The measure to reduce sugar levels include:
        
1. Exercise regularly.
               
2. Manage your carb intake.
               
3. Increase your fiber intake.
               
4. Drink water and stay hydrated.
               
5. Implement portion control.
               
6. Choose foods with a low glycemic index.
               
7. Manage stress levels.
               
8. Monitor your blood sugar levels."""
                elif float(s)>=161:
                        m1="Diabetes(Very High Sugar Level)!"
                        m2= """The measure to reduce sugar levels include:
        
1. Exercise regularly.
               
2. Manage your carb intake.
               
3. Increase your fiber intake.
               
4. Drink water and stay hydrated.
               
5. Implement portion control.
               
6. Choose foods with a low glycemic index.
               
7. Manage stress levels.
               
8. Monitor your blood sugar levels."""

        SUG1=Label(root,text= m1,font=("Times New Roman",30))
        
        SUG2=Label(root,text= m2,font=("Ariel",25),justify=LEFT,bd=10)
        SUG1.place(relx=0.35,rely=0.2)
        SUG2.place(relx=0.2,rely=0.3)
        
        
def SUGEntry():
        global l16
        global e9
        global b13


        delhome()
        
        l16.place(relx=0.3,rely=0.1)
        e9.place(relx=0.5,rely=0.1)
        b13.place(relx=0.7,rely=0.1)
def backPulse():
        global b11
        global PULL1
        global PULL2
        b11.place_forget()
        PULL1.place_forget()
        PULL2.place_forget()
        home()
def PulseRate():
        global e8
        global l15
        global b10
        global b11
        global PULL1
        global PULL2
        
        p=e8.get()
        something=0
        for i in e8.get():
                if(not(i.isdigit())):
                        something=1
        l15.place_forget()
        e8.place_forget()
        b10.place_forget()
        b11.place(relx=0,rely=0)
        if(something==1 or len(e8.get())==0):
                m2=("""The Pulse Rate you have entered is not valid.
Please check your input""")
                m1=""
        elif(float(p)>220-int(Age)):
                m2=("""The Heart Rate you have entered exceeds the maximum value
for your age.
Please check your input""")
        
                m1=""
        
        else:
                if float(p)<54:
                        m1="Amazing Level Fitness"
                        m2="""1.This is a Best Level of Fitness!!

2.This level of fitness most desirable

3.Try maintaing this level of fitness by engaging in various physical activities

4.Following a Good diet plan and maintaining your weight will also help maintain this level of fitness!!"""
                elif float(p)>=54 and float(p) <=60:
                        m1="Athlete Level Fitness!"
                        m2="""1.Very Good Level of Fitness!!
2. Even though you have a very good pulse rate there is still a small room for improvement

3. Daily physical excersises like walking, Yoga, jogging etc will be very helpful
in maintaining as well as improving your pulse rate

4. Maintaining a good diet plan including all the necessary amounts of nourishments will be very helpful

5.Try and maintain this level of fitness!!"""
                elif float(p)>60 and float(p)<=65:
                        m1="Excellent Fitness!"
                        m2="""1.Very Good Level of Fitness!!
2. Even though you have a very good pulse rate there is still a small room for improvement

3. Daily physical excersises like walking, Yoga, jogging etc will be very helpful
in maintaining as well as improving your pulse rate

4. Maintaining a good diet plan including all the necessary amounts of nourishments will be very helpful

5.Try and maintain this level of fitness!!"""
                elif float(p)>65 and float(p)<=70:
                        m1="Good Fitness!"
                        m2="""1.Good Level of Fitness!!
2.Even though you have good level of fitness there is still some room for improvement

3.To improve your pulse rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.


"""
                elif float(p)>70 and float(p)<=75:
                        m1="Above Average Fitness!"
                        m2="""1.You have a pulse rate which is slightly better than that of an average man

2.Since your pulse rate is slightly better than average, there is still a lot of room for improvement

3.To improve your pulse rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health."""
                elif float(p)>75 and float(p)<=85:
                        m1="Average Fitness!" 
                        m2="""1.You have an average pulse rate

2.Since your pulse rate is just average, improvement might be a necessity

3.To improve your pulse rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.

f. Manage your stress

g. Lose weight if necessary"""
                else:
                        m1="Poor Fitness!"
                        m2="""1.Very poor fitness level of fitness
2. This level of fitness is the most undesirable

3. If not improved, this can result in the some long term health issues

4. To improve your pulse rate over a long term, you can try the following:

a. Exercise: The easiest and most effective way to achieve a lasting lower heart rate is to do regular exercise.

b. Stay hydrated: When the body is dehydrated, the heart has to work harder to stabilize blood flow.
Throughout the day, drink plenty of sugar- and caffeine-free beverages, such as water and herbal tea.

c. Limit intake of stimulants, such as caffeine and nicotine: Stimulants can cause
dehydration, increasing the heart’s workload.

d. Limit alcohol intake: Most forms of alcohol dehydrate the body. Alcohol is also a toxin,
and the body must work harder to process and remove it.

e. Eat a healthy, balanced diet: Eating a varied diet rich in fruits, vegetables, lean proteins, nuts, and
legumes can help to improve the health of the heart, as well as overall health.

f. Manage your stress

g. Lose weight if necessary"""
        PULL1=Label(root,text= m1,font=("Times New Roman",30))
        
        PULL2=Label(root,text= m2,font=("Ariel",25),justify=LEFT,bd=10)
        PULL1.place(relx=0.45,rely=0.1)
        PULL2.place(relx=0.2,rely=0.2)
                        
        
        
def PULSEENTRY():
        global l15
        global e8
        global b10


        delhome()
        
        l15.place(relx=0.3,rely=0.1)
        e8.place(relx=0.5,rely=0.1)
        b10.place(relx=0.7,rely=0.1)
        
def backBPM():
        global BPML1
        global BPML2
        global b8
        BPML1.place_forget()
        BPML2.place_forget()
        b8.place_forget()
        home()
def BPM():
        global l8
        global l9
        global e6
        global e7
        global b7
        global BPML1
        global BPML2
        global b8
        something=0
        for i in e7.get():
                if(not(i.isdigit())):
                        something=1
        for i in e6.get():
                if(not(i.isdigit())):
                        something=1
        
        
        sys_pressure=(e6.get())
        dias_pressure=(e7.get())
        l13.place_forget()
        l14.place_forget()
        e6.place_forget()
        e7.place_forget()
        b7.place_forget()
        b8.place(relx=0,rely=0)
        if(something==1 or len(e7.get())==0 or len(e6.get())==0):
                m1=("""The blood pressure you have entered is not valid.
Please check your input""")
                m2=""
        else:
                if (((float(sys_pressure))<=120 and (float(sys_pressure))>=90) and ((float(dias_pressure))>=60 and (float(dias_pressure))<=90)):
                
                        m1=("Your Blood Pressure is in Optimal range!,")
                        m2=("""Try to maintain this blood pressure
Some tips to maintain your blood pressure are:

1. Eat healthy food

2. Maintain a healthy weight

3. Increase physical activity

4. Manage stress

5. Limit smoking

6. Limit alchohol consumption

7.Practice relaxation or slow, deep breathing

8.Monitor your blood pressure at home""")


                elif ((float(sys_pressure)>120 and float(sys_pressure)<180) and (float(dias_pressure)>90 and float(dias_pressure)<120)):
                        m1=("Your Blood Pressure is High!")
                        m2=("""Please follow the given routines to reduce blood pressure:
                
1.adopting a healthy, balanced diet and restricting your salt intake,

2.getting regular exercise.

3.cutting down on alcohol.

4.losing weight.

5.stopping smoking.

6.taking medication, such as angiotensin-converting enzyme (ACE) inhibitors or calcium channel blockers. """)
                elif (float(float(sys_pressure))<90 and float(dias_pressure)<60):
                        m1=("Your Blood Pressure is Low!")
                        m2=("""Please follow the given routines to increase blood pressure:
                
1.adopting a healthy, balanced diet and restricting your salt intake.

2.getting regular exercise.

3.cutting down on alcohol.

4.losing weight.

5.stopping smoking.

6.taking medication, such as angiotensin-converting enzyme (ACE) inhibitors or calcium channel blockers.""")
                elif(float(sys_pressure)>=180 and float(dias_pressure)>=120):
                        m1=("You have hypertensive crises!!!")
                        m2=("""You need immediate medical attention. Signs and symptoms of a hypertensive crisis that may be
life-threatening may include:

1.Severe chest pain

2.Severe headache, accompanied by confusion and blurred vision

3.Nausea and vomiting

4.Severe anxiety

5.Shortness of breath

6.Seizures

7.Unresponsiveness""")
                else:
                        m2=("")
                        m1=("""The blood pressure you have entered is not in a valid range.
Please check your input""")
        BPML1=Label(root,text= m1,font=("Times New Roman",30))
        
        BPML2=Label(root,text= m2,font=("Ariel",25),justify=LEFT,bd=10)
        BPML1.place(relx=0.35,rely=0.2)
        BPML2.place(relx=0.2,rely=0.3)
        
def BPMEntry():
        global l13
        global l14
        global e6
        global e7
        global b7
        global BPML1
        global BPML2


        delhome()
        
        l13.place(relx=0.0,rely=0.1)
        l14.place(relx=0.3,rely=0.1)
        e6.place(relx=0.2,rely=0.1)
        e7.place(relx=0.55,rely=0.1)
        b7.place(relx=0.7,rely=0.1)
        
        
        
        

def BMI():
        delhome()
        global b2
        global BMIL1
        global BMIL2
        global BMIL3
        global Weight
        global Height
        b3.place(relx=0,rely=0)
        bmi = (float(Weight)/((float(Height))/100)**2)
        bmi=round(bmi,2)

        m=("Your BMI is: "+str(bmi))

        if ( bmi < 16):
                    m1="You are severely underweight!"
                    m2="""The solutions are:

1.Don't drink water before meals. This can fill your stomach and make it harder to get in enough calories.

2.Eat more often.

3.Drink milk.

4.Try weight gainer shakes.

5.Use bigger plates. ...

6.Add cream to your coffee.

7.Take creatine.

8.Get quality sleep."""
        elif ( bmi >= 16 and bmi < 18.5):
            m1="Underweight!!"
            m2="""The solutions are:

1.Don't drink water before meals. This can fill your stomach and make it harder to get in enough calories.

2.Eat more often.

3.Drink milk.

4.Try weight gainer shakes.

5.Use bigger plates. ...

6.Add cream to your coffee.

7.Take creatine.

8.Get quality sleep."""
        elif ( bmi >= 18.5 and bmi < 25):
            m1="Healthy!"
            m2="YOU ARE HEALTHY!"

        elif ( bmi >= 25 and bmi < 30):
            m1="Overweight!"
            m2="""  The solutions are:

1.Eat a high protein breakfast.

2.Avoid sugary drinks and fruit juice.

3.Drink water before meals.

4.Choose weight-loss-friendly foods.

5.Eat soluble fiber.

6.Drink coffee or tea.

7.Base your diet on whole foods.

8.Eat slowly."""
            
        elif ( bmi >=30):
            m1="Severely Overweight!"
            m2="""The solution are:

1.Eat a high protein breakfast.

2.Avoid sugary drinks and fruit juice.

3.Drink water before meals.

4.Choose weight loss friendly foods.

5.Eat soluble fiber.

6.Drink coffee or tea.

7.Base your diet on whole foods.

8.Eat slowly"""
        
        BMIL1=Label(root,text= m,font=("Times New Roman",30))
        BMIL2=Label(root,text= m1,font=("Ariel",30))
        BMIL3=Label(root,text= m2,font=("Ariel",25),justify=LEFT,bd=10)
        BMIL1.place(relx=0.35,rely=0.1)
        BMIL2.place(relx=0.4,rely=0.2)
        BMIL3.place(relx=0.25,rely=0.3)
        

def Calories():
        delhome()
        
        
        global b5
        global CALL1
        global CALL2
        global Weight
        global Height
        global Age
        b5.place(relx=0,rely=0)
        
        if Gender=="M":
                Cal=66 + (6.2*(float(Weight))) + (12.7 * (float(Height))) - (6.76 * (float(Age)))
                Cal=round(Cal,2)
                m1=("The Calories burnt by the man is: "+str(Cal)+"cal")
        else:
                Cal=655.1 + (4.35 * (float(Weight))) + (4.7 * (float(Height)))-(4.7 * (float(Age)))
                Cal=round(Cal,2)
                m1=("The Calories burnt by the woman is: "+str(Cal)+"cal")
        m2=("""The various ways of improving your burn of calories per day are:

1.Brisk walking

2.Jogging

3.Cycling

4.Performing Yoga Asanas

5.Doing all sorts of physical exercise including outdoor sports""")
        CALL1=Label(root,text= m1,font=("Times New Roman",30))
        CALL2=Label(root,text=m2,font=("Ariel",25),justify=LEFT,bd=10)
        CALL1.place(relx=0.35,rely=0.1)
        CALL2.place(relx=0.25,rely=0.3)
def delhome():
        global l8
        global l9
        global l10
        global L11
        global l12
        global b2
        global b4
        l8.place_forget()
        l9.place_forget()
        l10.place_forget()
        L11.place_forget()
        l12.place_forget()
        b2.place_forget()
        b4.place_forget()
        b6.place_forget()
        b9.place_forget()
        b12.place_forget()
        b15.place_forget()
        
def backBMI():
        global b2
        global BMIL1
        global BMIL2
        global BMIL3
        BMIL1.place_forget()
        BMIL2.place_forget()
        BMIL3.place_forget()
        b3.place_forget()
        home()

def backCAL():
        global b5
        global CALL1
        global CALL2
        CALL1.place_forget()
        CALL2.place_forget()
        b5.place_forget()
        home()
        
        
def home():
        global l8
        global l9
        global l10
        global L11
        global l12
        global b2
        global b6
        global b9
        global b12
        global b15
        l8.place(relx=0.0,rely=0.2)
        l9.place(relx=0.3,rely=0.2)
        l10.place(relx=0.5,rely=0.2)
        L11.place(relx=0.7,rely=0.2)
        l12.place(relx=0.9,rely=0.2)
        b2.place(relx=0.25,rely=0.34)
        b4.place(relx=0.25,rely=0.45)
        b6.place(relx=0.25,rely=0.55)
        b9.place(relx=0.25,rely=0.65)
        b12.place(relx=0.25,rely=0.75)
        b15.place(relx=0.25,rely=0.85)

        
def onclick1():
        global Name
        global Age
        global Weight
        global Height
        global Gender
        global l8
        global l9
        global l10
        global L11
        global l12
        global b2
        count=0
        l7.place_forget()
        for i in e2.get():
                if(not(i.isdigit())):
                        count=1
        for i in e3.get():
                if(not(i.isdigit())):
                        count=1
        for i in e4.get():
                if(not(i.isdigit())):
                        count=1
        if(count==1 or ((e5.get())!="M" and (e5.get())!="F") or (len(e2.get())==0) or (len(e3.get())==0) or (len(e4.get())==0) or (len(e1.get())==0)):
                l7.place(relx=0.3,rely=0.8)
        else:
                for i in range(1,6):
                        Labels[i].place_forget()
                for i in range(0,5):
                        Entry[i].place_forget()
                b1.place_forget()
                Name=e1.get()
                Age=e2.get()
                Height=e3.get()
                Gender=e5.get()
                Weight=e4.get()
                l8=Label(root,text="Name: "+Name,font=("Times New Roman",30))
                l8.place(relx=0.0,rely=0.2)
                l9=Label(root,text="Age: "+Age+" years",font=("Times New Roman",30))
                l9.place(relx=0.3,rely=0.2)
                l10=Label(root,text="Height: "+Weight+" kg",font=("Times New Roman",30))
                l10.place(relx=0.5,rely=0.2)
                L11=Label(root,text="Weight: "+Height+" cm",font=("Times New Roman",30))
                L11.place(relx=0.7,rely=0.2)
                l12=Label(root,text="Gender: "+Gender,font=("Times New Roman",30))
                l12.place(relx=0.9,rely=0.2)
                b2.place(relx=0.25,rely=0.3)
                b4.place(relx=0.25,rely=0.4)
                b6.place(relx=0.25,rely=0.5)
                b9.place(relx=0.25,rely=0.6)
                b12.place(relx=0.25,rely=0.7)
                b15.place(relx=0.25,rely=0.8)
                
                
                
                
l1=Label(root,text="Fitness Module ",font=("Times New Roman",50))
l2=Label(root,text="Enter Name: ",font=("Ariel",25))
l3=Label(root,text="Enter Age(years): ",font=("Ariel",25))
l4=Label(root,text="Enter Height(cm): ",font=("Ariel",25))
l5=Label(root,text="Enter Weight(kg): ",font=("Ariel",25))
l6=Label(root,text="Enter Gender(M/F): ",font=("Ariel",25))
l7=Label(root,text="Invalid inputs!!!Please Enter valid inputs and try again",font=("Ariel",25))
l13=Label(root,text="Enter Systolic pressure: ",font=("Ariel",25))
l14=Label(root,text="Enter Diastolic pressure: ",font=("Ariel",25))
l15=Label(root,text="Enter Pulse Rate: ",font=("Ariel",25))
l16=Label(root,text="Enter Sugar Level: ",font=("Ariel",25))
l17=Label(root,text="Enter Heart Rate: ",font=("Ariel",25))
Labels=[l1,l2,l3,l4,l5,l6]

e1=Entry(root,width=25,bd=5,font=("Ariel",25))
e2=Entry(root,width=25,bd=5,font=("Ariel",25))
e3=Entry(root,width=25,bd=5,font=("Ariel",25))
e4=Entry(root,width=25,bd=5,font=("Ariel",25))
e5=Entry(root,width=25,bd=5,font=("Ariel",25))
e6=Entry(root,width=10,bd=5,font=("Ariel",25))
e7=Entry(root,width=10,bd=5,font=("Ariel",25))
e8=Entry(root,width=10,bd=5,font=("Ariel",25))
e9=Entry(root,width=10,bd=5,font=("Ariel",25))
e10=Entry(root,width=10,bd=5,font=("Ariel",25))
l1.place(relx=0.4,rely=0)
Entry=[e1,e2,e3,e4,e5]
for i in range(1,6):
        Labels[i].place(relx=0.3,rely=0.2+((i-1)/10))
for i in range(0,5):
        Entry[i].place(relx=0.5,rely=0.2+(i/10))
b1=Button(root,font=("Ariel",25),text="Submit",bd=10,width=15,bg="YELLOW",command=onclick1)
b2=Button(root,font=("Ariel",25),text="Calculate your BMI",bd=10,width=50,bg="YELLOW",command=BMI)
b3=Button(root,font=("Ariel",25),text="HOME",bd=10,width=15,bg="YELLOW",command=backBMI)
b4=Button(root,font=("Ariel",25),text="Calculate the number of calories you burn per day",bg="RED",bd=10,width=50,command=Calories)
b5=Button(root,font=("Ariel",25),text="HOME",bd=10,width=15,bg="YELLOW",command=backCAL)
b6=Button(root,font=("Ariel",25),text="Find out whether your BLOOD PRESSURE is in optimal range",bd=10,width=50,bg="ORANGE",command=BPMEntry)
b7=Button(root,font=("Ariel",25),text="Submit",bd=10,width=15,bg="YELLOW",command=BPM)
b8=Button(root,font=("Ariel",25),text="HOME",bd=10,width=15,bg="YELLOW",command=backBPM)
b9=Button(root,font=("Ariel",25),text="Find out your fitness level on the basis of your PULSE RATE",bd=10,width=50,bg="PINK",command=PULSEENTRY)
b10=Button(root,font=("Ariel",25),text="Submit",bd=10,width=15,bg="YELLOW",command=PulseRate,)
b11=Button(root,font=("Ariel",25),text="HOME",bd=10,width=15,bg="YELLOW",command=backPulse)
b12=Button(root,font=("Ariel",25),text="Find out whether your SUGAR LEVEL is in optimal range",bd=10,width=50,bg="GREEN",command=SUGEntry)
b13=Button(root,font=("Ariel",25),text="Submit",bd=10,width=15,bg="YELLOW",command=SUGAR)
b14=Button(root,font=("Ariel",25),text="HOME",bd=10,width=15,bg="YELLOW",command=backSUG)
b15=Button(root,font=("Ariel",25),text="Find out your fitness level on the basis of your HEART RATE",bd=10,width=50,bg="PURPLE",command=HRENTRY)
b16=Button(root,font=("Ariel",25),text="Submit",bd=10,width=15,bg="YELLOW",command=HR)
b17=Button(root,font=("Ariel",25),text="HOME",bd=10,width=15,bg="YELLOW",command=backHR)



b1.place(relx=0.43,rely=0.7)
root.mainloop()
